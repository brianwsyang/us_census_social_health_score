# %%
"""
@author: brianwsyang
@date: Sat Jul 27, 2019
"""

import pandas as pd
import re

# %%
edu_xls = pd.ExcelFile('Education.xls')

edu_sht_map = {}
for name in edu_xls.sheet_names:
    edu_sht_map[name] = edu_xls.parse(name)

edu_sht_map
# Out:
# {'Education 1970 to 2017':      Educational attainment for adults age 25 and older for the U.S., States, and counties, 1970-2017  \
#  0     Sources: Census Bureau, 1970, 1980, 1990, 2000...
#  1     For defintions of rural classifications, see U...
#  2     This table was prepared by USDA, Economic Rese...
#  3                                             FIPS Code
#  4                                                 00000
#  5                                                 01000
#  6                                                 01001
#  7                                                 01003
#  8                                                 01005
#  9                                                 01007
#  10                                                01009
#  11                                                01011
#  12                                                01013
#  13                                                01015
# ...

# %%
crm01_sheet_map = {}
for sht_name in crm01_xls.sheet_names:
    crm01_sheet_map[sht_name] = crm01_xls.parse(sht_name)

crm01_sheet_map
